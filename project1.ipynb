# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding = 'latin-1')

# %%
data.iloc[:5]
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
d1= data.groupby('Area')['Y2017'].sum()
print(d1)
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
d1.count()
# Out:
# 49

# %%
data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12124\76401030.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
data.groupby('Item')['Y2015','Y2018'].sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12124\385034823.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Item')['Y2015','Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
data['Y2014'].isnull().sum()
# Out:
# 1589

# %%
d1=data.groupby('Area')['Y2017'].sum()

# %%
d1.sort_values()
# Out:
# Area
# Sudan (former)                       0.00
# Ethiopia PDR                         0.00
# Comoros                             59.84
# Seychelles                         442.34
# Sao Tome and Principe            12662.63
# Cabo Verde                       14650.74
# Guinea-Bissau                    19102.77
# Lesotho                          21267.96
# Botswana                         22101.30
# Djibouti                         22729.91
# Gambia                           23154.18
# Gabon                            27979.64
# Liberia                          29342.20
# Namibia                          29874.89
# Central African Republic         29937.00
# Congo                            41181.68
# Togo                             49841.88
# Mauritius                        51114.83
# Eswatini                         54343.33
# Sierra Leone                     55311.33
# Chad                             71594.68
# Rwanda                           73663.69
# ...

# %%
d2=data[['Element','Area','Y2017']]

# %%
d2
# Out:
#                                       Element      Area     Y2017
# 0               Total Population - Both sexes   Algeria  41389.00
# 1                    Domestic supply quantity   Algeria      0.00
# 2               Food supply (kcal/capita/day)   Algeria   3341.00
# 3      Protein supply quantity (g/capita/day)   Algeria     92.82
# 4          Fat supply quantity (g/capita/day)   Algeria     80.19
# ...                                       ...       ...       ...
# 60938                                    Food  Zimbabwe     19.00
# 60939     Food supply quantity (kg/capita/yr)  Zimbabwe      1.33
# 60940           Food supply (kcal/capita/day)  Zimbabwe      1.00
# 60941  Protein supply quantity (g/capita/day)  Zimbabwe      0.04
# 60942      Fat supply quantity (g/capita/day)  Zimbabwe      0.02
#
# [60943 rows x 3 columns]

# %%
a = round(data['Y2017'].std(),2)
print(a)
# Out:
# 1671.86

# %%
b = round(data['Y2017'].mean(),2)
print(b)
# Out:
# 140.92
